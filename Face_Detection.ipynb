# %% [markdown]
# <a href="https://colab.research.google.com/github/yusrizaltomo/uts-pcd-face-detection/blob/main/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yusrizaltomo/uts-pcd-face-detection.git
# Out:
# Cloning into 'uts-pcd-face-detection'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 53 (delta 21), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (53/53), 5.16 MiB | 7.20 MiB/s, done.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
img = cv.imread('uts-pcd-face-detection/img/foto1.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x1280 at 0x7F2448B8F640>

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=960x1280 at 0x7F244B1F9820>

# %%
haar_cascade = cv.CascadeClassifier('uts-pcd-face-detection/haar_face.xml')

faces = haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=6)

print(f'Jumlah wajah yang terdeteksi = {len(faces)}')

for (x,y,width,height) in faces:
    cv.rectangle(img, (x,y), (x+width,y+height), (0,255,0), thickness=2)
# Out:
# Jumlah wajah yang terdeteksi = 2

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x1280 at 0x7F242432D850>
