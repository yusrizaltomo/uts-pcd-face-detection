# %% [markdown]
# <a href="https://colab.research.google.com/github/yusrizaltomo/uts-pcd-face-detection/blob/main/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yusrizaltomo/uts-pcd-face-detection.git
# Out:
# fatal: destination path 'uts-pcd-face-detection' already exists and is not an empty directory.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
img = cv.imread('uts-pcd-face-detection/img/group 2.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x828 at 0x7FE924132E50>

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=640x828 at 0x7FE924132A60>

# %%
haar_cascade = cv.CascadeClassifier('uts-pcd-face-detection/haar_face.xml')

faces_rect = haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

print(f'Jumlah wajah yang terdeteksi = {len(faces_rect)}')

for (x,y,width,height) in faces_rect:
    cv.rectangle(img, (x,y), (x+width,y+height), (0,255,0), thickness=2)
# Out:
# Jumlah wajah yang terdeteksi = 6

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x828 at 0x7FE9249A76A0>
